# %% [markdown]
# # Analyze Trader Activity
#
# Extract and analyze trader activity from explorer_blocks.

# %%
import json
import msgpack
import lz4.frame
from pathlib import Path
from collections import Counter, defaultdict
from decimal import Decimal
import pandas as pd

SAMPLES_DIR = Path('../hyperliquid_samples/explorer_blocks')

# %%
def load_blocks(filepath):
    filepath = Path(filepath)
    if filepath.suffix == '.json':
        with open(filepath) as f:
            return json.load(f)
    elif filepath.suffix == '.lz4':
        with open(filepath, 'rb') as f:
            data = lz4.frame.decompress(f.read())
            return msgpack.unpackb(data, raw=False)
    elif filepath.suffix == '.rmp':
        with open(filepath, 'rb') as f:
            return msgpack.unpack(f, raw=False)

# Load recent blocks
blocks = load_blocks(SAMPLES_DIR / '811681900.json')
print(f"Loaded {len(blocks)} blocks")
# Out:
# Loaded 100 blocks

# %% [markdown]
# ## Extract Trader Activity

# %%
def extract_trader_activity(blocks):
    """
    Extract activity per trader from blocks.
    Returns dict: address -> {orders, cancels, volume_usd, assets_traded}
    """
    activity = defaultdict(lambda: {
        'orders': 0,
        'cancels': 0,
        'modifies': 0,
        'assets': set(),
        'buy_orders': 0,
        'sell_orders': 0
    })
    
    for block in blocks:
        for tx in block.get('txs', []):
            user = tx.get('user')
            if not user:
                continue
                
            for action in tx.get('actions', []):
                action_type = action.get('type')
                
                if action_type == 'order':
                    for order in action.get('orders', []):
                        activity[user]['orders'] += 1
                        activity[user]['assets'].add(order.get('a'))
                        if order.get('b'):
                            activity[user]['buy_orders'] += 1
                        else:
                            activity[user]['sell_orders'] += 1
                            
                elif action_type in ('cancel', 'cancelByCloid'):
                    activity[user]['cancels'] += len(action.get('cancels', []))
                    
                elif action_type in ('modify', 'batchModify'):
                    activity[user]['modifies'] += 1
    
    # Convert sets to counts
    for user in activity:
        activity[user]['num_assets'] = len(activity[user]['assets'])
        activity[user]['assets'] = list(activity[user]['assets'])
    
    return dict(activity)

activity = extract_trader_activity(blocks)
print(f"Found {len(activity)} unique traders")
# Out:
# Found 679 unique traders

# %%
# Convert to DataFrame for analysis
df = pd.DataFrame.from_dict(activity, orient='index')
df.index.name = 'address'
df = df.reset_index()
df = df.sort_values('orders', ascending=False)
df.head(20)
# Out:
#                                         address  orders  cancels  modifies  \
# 12   0x362c5006ed0a405c35df4a138cb38d891f1a1a20    5186      240         0
# 2    0x13558be785661958932ceac35ba20de187275a42    5141      317         0
# 14   0x1a2e6afa298b1cc50939b4b2b0b430e3c1ef3459    4959      232         0
# 11   0x7dd6f02fef939cea86f0243358255f6b57a6cf0d    4888      158         0
# 60   0xaf2ac71f62f341e5823d6985492409e92c940447    4734      183         0
# 24   0xd47c1e51b759cb3754bb045ae57bc05aadcf58c2    4641      148         0
# 10   0xe29d84a6f37858d7f8017be454ee35726511e525    3000      255         0
# 16   0x4d969e59b312970cc07af266938a4433ccae0b4c    2982       71         0
# 40   0xa289ee1e56c0d5d041db762e6123e78af0f7d9ad    2953      546         0
# 68   0x54e3f54df4b10ff63f7284733ed735e8e1507c20    2772      399         0
# 3    0x3ac9b030594c1ef23a3e8fed9f62356b7bf98bf6    2461      358         0
# 50   0xabfae5ef417fec83a63dcdbff5a13f71d09045c5    1880      162         0
# 9    0xe3b3482482899b4890ec5a2093cba2a558d0c14f    1764        0         0
# 87   0xc6ef411a92428ec7f9fc0bc8e84ee3515bfeea7e    1716      163         0
# 88   0xf060e33cfa0727a224a184622606213e8f4e6a6f    1710        0         0
# 125  0x37c1e493c8a452ab3f5a6d01fda87795b91e7851    1656        0         0
# 140  0xaca2d79168f9e9072c089e5f7d6eb0daefc13915    1459       76         0
# 129  0x793660578d2628b0ec7e0e2b5c75a4847ae80706    1441       68         0
# 91   0x31ca8395cf837de08b24da3f660e77761dfb974b    1324     1202         0
# 148  0x010461c14e146ac35fe42271bdc1134ee31c703a    1173     1073         0
#
#                                                 assets  buy_orders  \
# 12                                                 [0]        5186
# 2                                    [0, 25, 214, 159]        5131
# 14                                                 [0]        4959
# 11                                                 [0]        4888
# 60                                                 [0]        4734
# 24                                                 [0]        4641
# 10                                                 [0]        3000
# 16                                                 [0]        2982
# 40                                                 [0]        2944
# 68                                                 [0]        2772
# 3                                                  [0]        2461
# 50                                                 [0]        1880
# 9                                                  [5]        1764
# 87                                                 [0]        1716
# 88                                                 [5]        1710
# 125                                                [5]        1656
# 140                                                [1]        1459
# 129                                                [1]        1441
# 91   [0, 8, 12, 13, 21, 23, 25, 26, 31, 32, 36, 38,...         635
# 148  [0, 5, 8, 12, 16, 21, 23, 25, 29, 31, 32, 37, ...         574
#
#      sell_orders  num_assets
# 12             0           1
# 2             10           4
# 14             0           1
# 11             0           1
# 60             0           1
# 24             0           1
# 10             0           1
# 16             0           1
# 40             9           1
# 68             0           1
# 3              0           1
# 50             0           1
# 9              0           1
# 87             0           1
# 88             0           1
# 125            0           1
# 140            0           1
# 129            0           1
# 91           689          83
# 148          599          88

# %%
# Top traders by order count
print("Top 10 Traders by Order Count:")
for _, row in df.head(10).iterrows():
    print(f"  {row['address'][:10]}... : {row['orders']:,} orders, {row['num_assets']} assets")
# Out:
# Top 10 Traders by Order Count:
#   0x362c5006... : 5,186 orders, 1 assets
#   0x13558be7... : 5,141 orders, 4 assets
#   0x1a2e6afa... : 4,959 orders, 1 assets
#   0x7dd6f02f... : 4,888 orders, 1 assets
#   0xaf2ac71f... : 4,734 orders, 1 assets
#   0xd47c1e51... : 4,641 orders, 1 assets
#   0xe29d84a6... : 3,000 orders, 1 assets
#   0x4d969e59... : 2,982 orders, 1 assets
#   0xa289ee1e... : 2,953 orders, 1 assets
#   0x54e3f54d... : 2,772 orders, 1 assets

# %%
# Distribution of order counts
print("\nOrder Count Distribution:")
print(df['orders'].describe())
# Out:
# Order Count Distribution:
# count     679.000000
# mean      136.343152
# std       561.418464
# min         0.000000
# 25%         1.000000
# 50%         3.000000
# 75%        17.000000
# max      5186.000000
# Name: orders, dtype: float64

# %% [markdown]
# ## Order Analysis

# %%
def extract_orders(blocks):
    """Extract all orders with details"""
    orders = []
    
    for block in blocks:
        block_time = block['header']['block_time']
        block_height = block['header']['height']
        
        for tx in block.get('txs', []):
            user = tx.get('user')
            
            for action in tx.get('actions', []):
                if action.get('type') == 'order':
                    for order in action.get('orders', []):
                        orders.append({
                            'block_time': block_time,
                            'block_height': block_height,
                            'user': user,
                            'asset': order.get('a'),
                            'side': 'buy' if order.get('b') else 'sell',
                            'price': order.get('p'),
                            'size': order.get('s'),
                            'reduce_only': order.get('r'),
                            'tif': order.get('t', {}).get('limit', {}).get('tif'),
                            'cloid': order.get('c')
                        })
    
    return orders

orders = extract_orders(blocks)
print(f"Extracted {len(orders):,} orders")
# Out:
# Extracted 92,577 orders

# %%
orders_df = pd.DataFrame(orders)
orders_df.head()
# Out:
#                       block_time  block_height  \
# 0  2025-11-28T22:44:28.368940020     811681801
# 1  2025-11-28T22:44:28.368940020     811681801
# 2  2025-11-28T22:44:28.368940020     811681801
# 3  2025-11-28T22:44:28.368940020     811681801
# 4  2025-11-28T22:44:28.368940020     811681801
#
#                                          user  asset side   price     size  \
# 0  0x847bd1ef4fede0fe191129894d63044843f4d473      1  buy  3034.7   2.5966
# 1  0x07fd7e702ba749ffa49c3a6c17fcd9e6c7b7082a      1  buy  3033.5  20.5319
# 2  0x13558be785661958932ceac35ba20de187275a42      0  buy   90941  0.01185
# 3  0x13558be785661958932ceac35ba20de187275a42      0  buy   90940  0.01185
# 4  0x13558be785661958932ceac35ba20de187275a42      0  buy   90939  0.01185
#
#    reduce_only  tif                               cloid
# 0        False  Alo  0x000000000000000000000000042ef3a0
# 1        False  Alo  0x00000000000000000143674b893ffac4
# 2        False  Alo  0x00000000239844b500001d671a7e1c90
# 3        False  Alo  0x00000000239844b600001d671a7e1c90
# 4        False  Alo  0x00000000239844b700001d671a7e1c90

# %%
# Order types distribution
print("Order Types (TIF):")
print(orders_df['tif'].value_counts())
# Out:
# Order Types (TIF):
# tif
# Alo               90667
# Ioc                1622
# Gtc                 267
# FrontendMarket       18
# Name: count, dtype: int64

# %%
# Buy vs Sell
print("\nBuy vs Sell:")
print(orders_df['side'].value_counts())
# Out:
# Buy vs Sell:
# side
# buy     84507
# sell     8070
# Name: count, dtype: int64

# %%
# Most traded assets
print("\nTop 10 Assets by Order Count:")
print(orders_df['asset'].value_counts().head(10))
# Out:
# Top 10 Assets by Order Count:
# asset
# 0        66910
# 1         7508
# 5         6640
# 25        1799
# 159        608
# 10107      532
# 60         370
# 214        332
# 174        329
# 10156      277
# Name: count, dtype: int64

# %% [markdown]
# ## Identify Potential Fills (IOC Orders)
#
# IOC (Immediate or Cancel) orders that cross the spread result in fills.
# ALO (Add Liquidity Only) orders never fill immediately.

# %%
# IOC orders are potential takers
ioc_orders = orders_df[orders_df['tif'] == 'Ioc']
print(f"IOC orders (potential fills): {len(ioc_orders):,}")

# ALO orders are makers only
alo_orders = orders_df[orders_df['tif'] == 'Alo']
print(f"ALO orders (makers only): {len(alo_orders):,}")
# Out:
# IOC orders (potential fills): 1,622
# ALO orders (makers only): 90,667

# %%
# IOC order details
print("\nSample IOC Orders:")
ioc_orders.head(10)
# Out:
# Sample IOC Orders:
#                         block_time  block_height  \
# 922  2025-11-28T22:44:28.368940020     811681801
# 923  2025-11-28T22:44:28.368940020     811681801
# 924  2025-11-28T22:44:28.368940020     811681801
# 925  2025-11-28T22:44:28.368940020     811681801
# 926  2025-11-28T22:44:28.368940020     811681801
# 927  2025-11-28T22:44:28.368940020     811681801
# 928  2025-11-28T22:44:28.368940020     811681801
# 929  2025-11-28T22:44:28.368940020     811681801
# 930  2025-11-28T22:44:28.368940020     811681801
# 931  2025-11-28T22:44:28.368940020     811681801
#
#                                            user  asset side    price     size  \
# 922  0x223537ac9a856c31f4043e86ced86bb29f06653e    122  buy  0.28107     4851
# 923  0x14ecb8b25e270b31cc270e3dd3ee220dd5dce16e      0  buy    90934    0.782
# 924  0xa775d1bd91ee2cc4cae6113e5fd9c0c17b355277      5  buy   137.51    35.33
# 925  0xa775d1bd91ee2cc4cae6113e5fd9c0c17b355277      0  buy    90931  0.02414
# 926  0xb6a766f531fa8e222f460df11d62b0f84b7b65f3      1  buy   3034.7    12.82
# 927  0xa775d1bd91ee2cc4cae6113e5fd9c0c17b355277      0  buy    90933  0.02414
# 928  0x5306cb5adfbaf940ce3dba0ac41d903dc70a766e      0  buy    90929  0.00021
# 929  0xb6a766f531fa8e222f460df11d62b0f84b7b65f3      1  buy   3034.7    12.82
# 930  0xa775d1bd91ee2cc4cae6113e5fd9c0c17b355277     25  buy   2.1816     1521
# 931  0xa775d1bd91ee2cc4cae6113e5fd9c0c17b355277     25  buy   2.1814     1521
#
#      reduce_only  tif                               cloid
# 922        False  Ioc  0x0000000000000000000000000444a764
# 923        False  Ioc  0x0000000000004bb30000147e62f51c92
# 924        False  Ioc  0x000000000000000000000000042c5415
# 925        False  Ioc  0x000000000000000000000000042c5412
# 926        False  Ioc  0x00000000000f6d810000134dcb731c93
# 927        False  Ioc  0x000000000000000000000000042c5413
# 928        False  Ioc  0x559a63adef6784e7615f6659672fe700
# 929        False  Ioc  0x00000000000f6d830000134dcb731c93
# 930        False  Ioc  0x000000000000000000000000042c541c
# 931        False  Ioc  0x000000000000000000000000042c540b
